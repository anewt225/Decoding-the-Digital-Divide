# %% [markdown]
# ## merge datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dp02 = pd.read_pickle('../data/census/ACS_5yr_DP02_2018.pkl')
dp02.head()
# Out:
# 0    LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 1  0102650      11557        430       11557  -888888888       7879
# 2  0102670       3079        238        3079  -888888888       1588
# 3  0102700      14462        421       14462  -888888888       8813
# 4  0102730       7530        262        7530  -888888888       4935
# 5  0102760       2671        205        2671  -888888888       1839
#
# 0 DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... DP02_0151EA DP02_0151MA  \
# 1        368        68.2         3.4       2803  ...        None        None
# 2        256        51.6         7.8        451  ...        None        None
# 3        424        60.9         3.1       4413  ...        None        None
# 4        279        65.5         3.1       1688  ...        None        None
# 5        167        68.9         4.6        726  ...        None        None
#
# 0 DP02_0151PEA DP02_0151PMA DP02_0152EA DP02_0152MA DP02_0152PEA DP02_0152PMA  \
# ...

# %%
dp03 = pd.read_pickle('../data/census/ACS_5yr_DP03_2018.pkl')
dp03.head()
# Out:
# 0    LEAID DP03_0001E DP03_0001M DP03_0001PE DP03_0001PM DP03_0002E  \
# 1  0102650      23777        721       23777  -888888888      13522
# 2  0102670       7699         79        7699  -888888888       2658
# 3  0102700      28325        461       28325  -888888888      17581
# 4  0102730      16837         67       16837  -888888888       7978
# 5  0102760       4988        320        4988  -888888888       2473
#
# 0 DP03_0002M DP03_0002PE DP03_0002PM DP03_0003E  ... DP03_0136EA DP03_0136MA  \
# 1        753        56.9         2.7      13522  ...         (X)         (X)
# 2        409        34.5         5.3       2651  ...         (X)         (X)
# 3        774        62.1         2.6      16855  ...         (X)         (X)
# 4        354        47.4         2.1       7978  ...         (X)         (X)
# 5        264        49.6         3.8       2473  ...         (X)         (X)
#
# 0 DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA DP03_0137PEA DP03_0137PMA  \
# ...

# %%
dp04 = pd.read_pickle('../data/census/ACS_5yr_DP04_2018.pkl')
dp04.head()
# Out:
# 0    LEAID DP04_0001E DP04_0001M DP04_0001PE DP04_0001PM DP04_0002E  \
# 1  0102650      13658        411       13658  -888888888      11557
# 2  0102670       4751         85        4751  -888888888       3079
# 3  0102700      17079        414       17079  -888888888      14462
# 4  0102730       9557        102        9557  -888888888       7530
# 5  0102760       3254        241        3254  -888888888       2671
#
# 0 DP04_0002M DP04_0002PE DP04_0002PM DP04_0003E  ... DP04_0142MA DP04_0142EA  \
# 1        430        84.6         2.5       2101  ...        None        None
# 2        238        64.8         5.0       1672  ...        None        None
# 3        421        84.7         2.4       2617  ...        None        None
# 4        262        78.8         2.6       2027  ...        None        None
# 5        205        82.1         4.3        583  ...        None        None
#
# 0 DP04_0142PEA DP04_0142PMA DP04_0143MA DP04_0143EA DP04_0143PMA DP04_0143PEA  \
# ...

# %%
dp05 = pd.read_pickle('../data/census/ACS_5yr_DP05_2018.pkl')
dp05.head()
# Out:
# 0   DP05_0031PM DP05_0032E    DP05_0032M DP05_0032PE DP05_0032PM DP05_0033E  \
# 1           3.0       81.4           9.8  -888888888  -888888888      29230
# 2  -888888888.0       69.1  -555555555.0  -888888888  -888888888       9486
# 3           2.9       60.9           7.5  -888888888  -888888888      36641
# 4           0.9       77.1           2.9  -888888888  -888888888      20298
# 5           6.1       70.4          17.5  -888888888  -888888888       6199
#
# 0  DP05_0033M DP05_0033PE DP05_0033PM DP05_0034E  ... DP05_0029PEA  \
# 1         882       29230  -888888888      29012  ...         None
# 2  -555555555        9486  -888888888       9486  ...         None
# 3          36       36641  -888888888      35214  ...         None
# 4  -555555555       20298  -888888888      20037  ...         None
# 5         358        6199  -888888888       6058  ...         None
#
# 0 DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA DP05_0031EA  \
# ...

# %%
two_and_three = pd.merge(dp02, dp03, how='inner', on='LEAID')

# %%
four_and_five = pd.merge(dp04, dp05, how='inner', on='LEAID')

# %%
ACS_ALL_2018 = pd.merge(two_and_three, four_and_five, how='inner', on='LEAID')

# %%
ACS_ALL_2018.to_pickle('../data/ACS_ALL_2018.pkl')

# %%
assessments = pd.read_pickle('../data/assessments_2018.pkl')

# %%
assessments.head()
# Out:
#    STNAM_x  FIPST_x    leaid ST_LEAID_x           LEANM_x DATE_CUR_x  \
# 0  ALABAMA        1  0100005     AL-101  Albertville City    27MAR19
# 1  ALABAMA        1  0100006     AL-048   Marshall County    27MAR19
# 2  ALABAMA        1  0100007     AL-158       Hoover City    27MAR19
# 3  ALABAMA        1  0100008     AL-169      Madison City    27MAR19
# 4  ALABAMA        1  0100011     AL-167        Leeds City    27MAR19
#
#    ALL_MTH00NUMVALID_1718 ALL_MTH00PCTPROF_1718 MAM_MTH00NUMVALID_1718  \
# 0                    2892                    45                      5
# 1                    2987                    43                     12
# 2                    7551                    70                      5
# 3                    5668                    76                     47
# 4                    1017                    40                      2
#
#   MAM_MTH00PCTPROF_1718  ... MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718  \
# ...

# %%
assessments.rename(columns={'leaid': 'LEAID'}, inplace=True)
assessments.head()
# Out:
#    STNAM_x  FIPST_x    LEAID ST_LEAID_x           LEANM_x DATE_CUR_x  \
# 0  ALABAMA        1  0100005     AL-101  Albertville City    27MAR19
# 1  ALABAMA        1  0100006     AL-048   Marshall County    27MAR19
# 2  ALABAMA        1  0100007     AL-158       Hoover City    27MAR19
# 3  ALABAMA        1  0100008     AL-169      Madison City    27MAR19
# 4  ALABAMA        1  0100011     AL-167        Leeds City    27MAR19
#
#    ALL_MTH00NUMVALID_1718 ALL_MTH00PCTPROF_1718 MAM_MTH00NUMVALID_1718  \
# 0                    2892                    45                      5
# 1                    2987                    43                     12
# 2                    7551                    70                      5
# 3                    5668                    76                     47
# 4                    1017                    40                      2
#
#   MAM_MTH00PCTPROF_1718  ... MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718  \
# ...

# %%
poverty = pd.read_pickle('../data/poverty_2018.pkl')

# %%
poverty.head()
# Out:
# 0       SAEPOVRAT5_17RV_PT
# LEAID
# 0100001               12.4
# 0100003               15.2
# 0100005               30.1
# 0100006               26.6
# 0100007                7.3

# %%
poverty_and_assessment = pd.merge(poverty, assessments, how='inner', on='LEAID')
poverty_and_assessment.head()
# Out:
#      LEAID SAEPOVRAT5_17RV_PT  STNAM_x  FIPST_x ST_LEAID_x           LEANM_x  \
# 0  0100005               30.1  ALABAMA        1     AL-101  Albertville City
# 1  0100006               26.6  ALABAMA        1     AL-048   Marshall County
# 2  0100007                7.3  ALABAMA        1     AL-158       Hoover City
# 3  0100008                8.3  ALABAMA        1     AL-169      Madison City
# 4  0100011               16.9  ALABAMA        1     AL-167        Leeds City
#
#   DATE_CUR_x  ALL_MTH00NUMVALID_1718 ALL_MTH00PCTPROF_1718  \
# 0    27MAR19                    2892                    45
# 1    27MAR19                    2987                    43
# 2    27MAR19                    7551                    70
# 3    27MAR19                    5668                    76
# 4    27MAR19                    1017                    40
#
#   MAM_MTH00NUMVALID_1718  ... MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718  \
# ...

# %%
COMPLETE_df = pd.merge(ACS_ALL_2018, poverty_and_assessment, on='LEAID', how='inner')
COMPLETE_df.head()
# Out:
#      LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 0  0102650      11557        430       11557  -888888888       7879
# 1  0102670       3079        238        3079  -888888888       1588
# 2  0102700      14462        421       14462  -888888888       8813
# 3  0102730       7530        262        7530  -888888888       4935
# 4  0102760       2671        205        2671  -888888888       1839
#
#   DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... MIL_RLA05NUMVALID_1718  \
# 0        368        68.2         3.4       2803  ...                      4
# 1        256        51.6         7.8        451  ...                      1
# 2        424        60.9         3.1       4413  ...                     10
# 3        279        65.5         3.1       1688  ...                    NaN
# 4        167        68.9         4.6        726  ...                    NaN
#
#   MIL_RLA05PCTPROF_1718 MIL_RLA06NUMVALID_1718 MIL_RLA06PCTPROF_1718  \
# ...

# %%
COMPLETE_df.set_index('LEAID', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-8b4fe6143423> in <module>
# ----> 1 COMPLETE_df.set_index('LEAID', inplace=True)
#
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4543
#    4544         if missing:
# -> 4545             raise KeyError(f"None of {missing} are in the columns")
#    4546
#    4547         if inplace:
#
# KeyError: "None of ['LEAID'] are in the columns"

# %%
COMPLETE_df.to_pickle('../data/COMPLETE_df.pkl')

# %%
COMPLETE_df = pd.read_pickle('../data/COMPLETE_df.pkl')
COMPLETE_df.head()
# Out:
#         DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E DP02_0002M  \
# LEAID
# 0102650      11557        430       11557  -888888888       7879        368
# 0102670       3079        238        3079  -888888888       1588        256
# 0102700      14462        421       14462  -888888888       8813        424
# 0102730       7530        262        7530  -888888888       4935        279
# 0102760       2671        205        2671  -888888888       1839        167
#
#         DP02_0002PE DP02_0002PM DP02_0003E DP02_0003M  ...  \
# LEAID                                                  ...
# 0102650        68.2         3.4       2803        335  ...
# 0102670        51.6         7.8        451        152  ...
# 0102700        60.9         3.1       4413        399  ...
# 0102730        65.5         3.1       1688        199  ...
# 0102760        68.9         4.6        726        127  ...
#
#         MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718 MIL_RLA06NUMVALID_1718  \
# ...

# %%
COMPLETE_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10362 entries, 0102650 to 5502880
# Columns: 4703 entries, DP02_0001E to MIL_RLAHSPCTPROF_1718
# dtypes: int64(4), object(4699)
# memory usage: 371.9+ MB

# %%
filtered_df = COMPLETE_df[['ALL_RLA00PCTPROF_1718','ALL_MTH00PCTPROF_1718','DP02_0151PE','DP02_0152PE','SAEPOVRAT5_17RV_PT','DP05_0037PE','DP02_0066PE','DP03_0062E','DP04_0134E','DP03_0009PE','DP02_0112PE','DP02_0071PE']]
filtered_df.to_pickle('filtered_df.pkl')
filtered_df.head()
# Out:
#         ALL_RLA00PCTPROF_1718 ALL_MTH00PCTPROF_1718 DP02_0151PE DP02_0152PE  \
# LEAID
# 0102650                    48                    48        81.2        72.9
# 0102670                    17                    15        55.9        46.2
# 0102700                    41                    43        83.5        68.1
# 0102730                    37                    29        72.9        62.8
# 0102760                    48                    53        81.5        70.5
#
#         SAEPOVRAT5_17RV_PT DP05_0037PE DP02_0066PE DP03_0062E DP04_0134E  \
# LEAID
# 0102650               16.5        89.2        83.4      48161        750
# 0102670                 49        29.9        78.1      23561        574
# 0102700               32.3        49.4        84.2      40218        825
# 0102730               29.4        56.0        80.6      37458        456
# 0102760               27.9        88.8        82.8      36306        492
#
#         DP03_0009PE DP02_0112PE DP02_0071PE
# LEAID
# ...

# %%
filtered_df.rename(columns = {'ALL_RLA00PCTPROF_1718': 'reading_score', 'ALL_MTH00PCTPROF_1718': 'math_score',
                   'DP02_0151PE':'comp_pct', 'DP02_0152PE':'broadband_pct', 'SAEPOVRAT5_17RV_PT':'poverty_ratio',
                   'DP05_0037PE':'white_pct', 'DP02_0066PE':'college_pct','DP03_0062E':'median_income','DP04_0134E':'median_rent',
                   'DP03_0009PE':'unemployment_pct', 'DP02_0112PE':'home_lang_not_eng', 'DP02_0071PE':'disability_pct'},
                inplace=True)
# Out:
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py:4290: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
filtered_df.head()
# Out:
#         reading_score math_score comp_pct broadband_pct poverty_ratio  \
# LEAID
# 0102650            48         48     81.2          72.9          16.5
# 0102670            17         15     55.9          46.2            49
# 0102700            41         43     83.5          68.1          32.3
# 0102730            37         29     72.9          62.8          29.4
# 0102760            48         53     81.5          70.5          27.9
#
#         white_pct college_pct median_income median_rent unemployment_pct  \
# LEAID
# 0102650      89.2        83.4         48161         750              7.8
# 0102670      29.9        78.1         23561         574             12.3
# 0102700      49.4        84.2         40218         825              9.2
# 0102730      56.0        80.6         37458         456             10.6
# 0102760      88.8        82.8         36306         492              7.3
#
#         home_lang_not_eng disability_pct
# LEAID
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10362 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      10362 non-null  object
#  1   math_score         10362 non-null  object
#  2   comp_pct           10362 non-null  object
#  3   broadband_pct      10362 non-null  object
#  4   poverty_ratio      10362 non-null  object
#  5   white_pct          10362 non-null  object
#  6   college_pct        10362 non-null  object
#  7   median_income      10362 non-null  object
#  8   median_rent        10362 non-null  object
#  9   unemployment_pct   10362 non-null  object
#  10  home_lang_not_eng  10362 non-null  object
#  11  disability_pct     10362 non-null  object
# dtypes: object(12)
# memory usage: 1.0+ MB

# %%
filtered_df['poverty_ratio'] = pd.to_numeric(filtered_df['poverty_ratio'])
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10362 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      10362 non-null  object
#  1   math_score         10362 non-null  object
#  2   comp_pct           10362 non-null  object
#  3   broadband_pct      10362 non-null  object
#  4   poverty_ratio      10362 non-null  float64
#  5   white_pct          10362 non-null  object
#  6   college_pct        10362 non-null  object
#  7   median_income      10362 non-null  object
#  8   median_rent        10362 non-null  object
#  9   unemployment_pct   10362 non-null  object
#  10  home_lang_not_eng  10362 non-null  object
#  11  disability_pct     10362 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 1.0+ MB
# <ipython-input-59-00bc762e3de6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_df['comp_pct'] = pd.to_numeric(filtered_df['comp_pct'])
filtered_df['broadband_pct'] = pd.to_numeric(filtered_df['broadband_pct'])
filtered_df['white_pct'] = pd.to_numeric(filtered_df['white_pct'])
filtered_df['college_pct'] = pd.to_numeric(filtered_df['college_pct'])
filtered_df['median_income'] = pd.to_numeric(filtered_df['median_income'])
filtered_df['median_rent'] = pd.to_numeric(filtered_df['median_rent'])
filtered_df['unemployment_pct'] = pd.to_numeric(filtered_df['unemployment_pct'])
filtered_df['home_lang_not_eng'] = pd.to_numeric(filtered_df['home_lang_not_eng'])
filtered_df['disability_pct'] = pd.to_numeric(filtered_df['disability_pct'])
# Out:
# <ipython-input-60-5b7fa5f52d95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['comp_pct'] = pd.to_numeric(filtered_df['comp_pct'])
# <ipython-input-60-5b7fa5f52d95>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['broadband_pct'] = pd.to_numeric(filtered_df['broadband_pct'])
# <ipython-input-60-5b7fa5f52d95>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10362 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      10362 non-null  object
#  1   math_score         10362 non-null  object
#  2   comp_pct           10362 non-null  float64
#  3   broadband_pct      10362 non-null  float64
#  4   poverty_ratio      10362 non-null  float64
#  5   white_pct          10362 non-null  float64
#  6   college_pct        10362 non-null  float64
#  7   median_income      10362 non-null  int64
#  8   median_rent        10362 non-null  int64
#  9   unemployment_pct   10362 non-null  float64
#  10  home_lang_not_eng  10362 non-null  float64
#  11  disability_pct     10362 non-null  float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 1.0+ MB

# %%
filtered_df.reading_score = filtered_df.reading_score.apply(str)
PS_values = filtered_df[filtered_df['reading_score'] == "PS" ].index
period_values = filtered_df[filtered_df['reading_score'] == "." ].index
LE_values = filtered_df[filtered_df.reading_score.str.contains("LE")].index
GT_values = filtered_df[filtered_df.reading_score.str.contains("GE")].index
GE_values = filtered_df[filtered_df.reading_score.str.contains("GT")].index
LT_values = filtered_df[filtered_df.reading_score.str.contains("LT")].index

filtered_df.drop(PS_values, inplace = True)
filtered_df.drop(period_values, inplace = True)
filtered_df.drop(LT_values, inplace = True)
filtered_df.drop(LE_values, inplace = True)
filtered_df.drop(GT_values, inplace = True)
filtered_df.drop(GE_values, inplace = True)
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10251 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      10251 non-null  object
#  1   math_score         10251 non-null  object
#  2   comp_pct           10251 non-null  float64
#  3   broadband_pct      10251 non-null  float64
#  4   poverty_ratio      10251 non-null  float64
#  5   white_pct          10251 non-null  float64
#  6   college_pct        10251 non-null  float64
#  7   median_income      10251 non-null  int64
#  8   median_rent        10251 non-null  int64
#  9   unemployment_pct   10251 non-null  float64
#  10  home_lang_not_eng  10251 non-null  float64
#  11  disability_pct     10251 non-null  float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 1.0+ MB
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\generic.py:5159: SettingWithCopyWarning:
# ...

# %%
filtered_df.math_score = filtered_df.math_score.apply(str)
PS_values = filtered_df[filtered_df['math_score'] == "PS" ].index
period_values = filtered_df[filtered_df['math_score'] == "." ].index
LE_values = filtered_df[filtered_df.math_score.str.contains("LE")].index
GT_values = filtered_df[filtered_df.math_score.str.contains("GE")].index
GE_values = filtered_df[filtered_df.math_score.str.contains("GT")].index
LT_values = filtered_df[filtered_df.math_score.str.contains("LT")].index

filtered_df.drop(PS_values, inplace = True)
filtered_df.drop(period_values, inplace = True)
filtered_df.drop(LT_values, inplace = True)
filtered_df.drop(LE_values, inplace = True)
filtered_df.drop(GT_values, inplace = True)
filtered_df.drop(GE_values, inplace = True)
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9988 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      9988 non-null   object
#  1   math_score         9988 non-null   object
#  2   comp_pct           9988 non-null   float64
#  3   broadband_pct      9988 non-null   float64
#  4   poverty_ratio      9988 non-null   float64
#  5   white_pct          9988 non-null   float64
#  6   college_pct        9988 non-null   float64
#  7   median_income      9988 non-null   int64
#  8   median_rent        9988 non-null   int64
#  9   unemployment_pct   9988 non-null   float64
#  10  home_lang_not_eng  9988 non-null   float64
#  11  disability_pct     9988 non-null   float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 1.3+ MB

# %%
def score_cleaner(score):
    score = str(score)
    
    if "-" in score:
        x, y = score.split("-")
        score = (int(x) + int(y))/ 2
        return round(int((score)))
    else:
        return int(score)

# %%
filtered_df.reading_score = filtered_df.reading_score.apply(score_cleaner)
filtered_df.math_score = filtered_df.math_score.apply(score_cleaner)
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9988 entries, 0102650 to 5502880
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      9988 non-null   int64
#  1   math_score         9988 non-null   int64
#  2   comp_pct           9988 non-null   float64
#  3   broadband_pct      9988 non-null   float64
#  4   poverty_ratio      9988 non-null   float64
#  5   white_pct          9988 non-null   float64
#  6   college_pct        9988 non-null   float64
#  7   median_income      9988 non-null   int64
#  8   median_rent        9988 non-null   int64
#  9   unemployment_pct   9988 non-null   float64
#  10  home_lang_not_eng  9988 non-null   float64
#  11  disability_pct     9988 non-null   float64
# dtypes: float64(8), int64(4)
# memory usage: 1.3+ MB

# %%
filtered_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-83e62557cabb> in <module>
# ----> 1 filtered_df.describe()
#
# NameError: name 'filtered_df' is not defined

# %%
filtered_df['composite_score'] = (filtered_df['reading_score'] + filtered_df['math_score'])/2
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9988 entries, 0102650 to 5502880
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      9988 non-null   int64
#  1   math_score         9988 non-null   int64
#  2   comp_pct           9988 non-null   float64
#  3   broadband_pct      9988 non-null   float64
#  4   poverty_ratio      9988 non-null   float64
#  5   white_pct          9988 non-null   float64
#  6   college_pct        9988 non-null   float64
#  7   median_income      9988 non-null   int64
#  8   median_rent        9988 non-null   int64
#  9   unemployment_pct   9988 non-null   float64
#  10  home_lang_not_eng  9988 non-null   float64
#  11  disability_pct     9988 non-null   float64
#  12  composite_score    9988 non-null   float64
# dtypes: float64(9), int64(4)
# memory usage: 1.4+ MB
# <ipython-input-69-e5848793fb0c>:1: SettingWithCopyWarning:
# ...

# %%
filtered_df.to_pickle('../data/CLEANED_df.pkl')

# %%
cleaned_df = pd.read_pickle('../data/CLEANED_df.pkl')

# %%
cleaned_df.head()
# Out:
#          reading_score  math_score  comp_pct  broadband_pct  poverty_ratio  \
# LEAID
# 0102650             48          48      81.2           72.9           16.5
# 0102670             17          15      55.9           46.2           49.0
# 0102700             41          43      83.5           68.1           32.3
# 0102730             37          29      72.9           62.8           29.4
# 0102760             48          53      81.5           70.5           27.9
#
#          white_pct  college_pct  median_income  median_rent  unemployment_pct  \
# LEAID
# 0102650       89.2         83.4          48161          750               7.8
# 0102670       29.9         78.1          23561          574              12.3
# 0102700       49.4         84.2          40218          825               9.2
# 0102730       56.0         80.6          37458          456              10.6
# 0102760       88.8         82.8          36306          492               7.3
#
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9988 entries, 0102650 to 5502880
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reading_score      9988 non-null   int64
#  1   math_score         9988 non-null   int64
#  2   comp_pct           9988 non-null   float64
#  3   broadband_pct      9988 non-null   float64
#  4   poverty_ratio      9988 non-null   float64
#  5   white_pct          9988 non-null   float64
#  6   college_pct        9988 non-null   float64
#  7   median_income      9988 non-null   int64
#  8   median_rent        9988 non-null   int64
#  9   unemployment_pct   9988 non-null   float64
#  10  home_lang_not_eng  9988 non-null   float64
#  11  disability_pct     9988 non-null   float64
#  12  composite_score    9988 non-null   float64
# dtypes: float64(9), int64(4)
# memory usage: 1.1+ MB

# %%
cleaned_df.describe()
# Out:
#        reading_score   math_score     comp_pct  broadband_pct  poverty_ratio  \
# count    9988.000000  9988.000000  9988.000000    9988.000000    9988.000000
# mean       49.785342    45.383260    85.306278      75.330447      16.683911
# std        16.486362    17.658938     6.996305      10.036105       9.059927
# min         2.000000     2.000000    25.300000      14.600000       1.300000
# 25%        37.000000    32.000000    81.400000      69.400000      10.000000
# 50%        49.000000    44.000000    85.900000      76.000000      15.300000
# 75%        62.000000    57.000000    90.300000      82.400000      21.800000
# max        94.000000    98.000000   100.000000     100.000000      65.400000
#
#          white_pct  college_pct  median_income   median_rent  \
# count  9988.000000  9988.000000   9.988000e+03  9.988000e+03
# mean     85.752473    88.112565  -1.417178e+05 -4.003978e+06
# std      16.086297     7.147725   1.155382e+07  5.151800e+07
# ...

# %%
import seaborn as sns

# %%
sns.lmplot(x='composite_score', y='comp_pct', data=cleaned_df)

# %%
sns.lmplot(x='composite_score', y='broadband_pct', data=cleaned_df)

# %%
sns.lmplot(x='reading_score', y='comp_pct', data=cleaned_df)

# %%
sns.lmplot(x='reading_score', y='comp_pct', data=cleaned_df)

# %%
cleaned_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFF5BBD3D0>,
# ...
#       dtype=object)

# %%
cleaned_df.math_score.hist()

# %%
cleaned_df.reading_score.hist()

# %%
cleaned_df.composite_score.hist()

# %%
cleaned_df.broadband_pct.hist()

# %%
cleaned_df.comp_pct.hist()

# %%
corr = cleaned_df.corr()

# %%
sns.heatmap(corr)

# %%
sns.pairplot(cleaned_df)

# %%
cleaned_df.median_income.describe()
# Out:
# count    9.988000e+03
# mean    -1.417178e+05
# std      1.155382e+07
# min     -6.666667e+08
# 25%      4.504200e+04
# 50%      5.402200e+04
# 75%      6.592550e+04
# max      2.500010e+05
# Name: median_income, dtype: float64

# %%
import missingno as msno

# %%
# %matplotlib inline

# %%
msno.matrix(filtered_df)
# Out:
# <AxesSubplot:>

# %%
filtered_df = rla_2018[['LEAID','ALL_RLAHSPCTPROF_1718']].dropna()
filtered_df.columns = filtered_df.columns.str.lower()
filtered_df.rename(columns={'all_rlahspctprof_1718': 'rla_score'}, inplace=True)
filtered_df.leaid = filtered_df.leaid.apply(str)
filtered_df.rla_score = filtered_df.rla_score.apply(str)
filtered_df.leaid = filtered_df.leaid.str.zfill(7)
filtered_df = pd.DataFrame(data=filtered_df)

PS_values = filtered_df[filtered_df['rla_score'] == "PS" ].index
period_values = filtered_df[filtered_df['rla_score'] == "." ].index
LE_values = filtered_df[filtered_df.rla_score.str.contains("LE")].index
GT_values = filtered_df[filtered_df.rla_score.str.contains("GE")].index
GE_values = filtered_df[filtered_df.rla_score.str.contains("GT")].index
LT_values = filtered_df[filtered_df.rla_score.str.contains("LT")].index

filtered_df.drop(PS_values, inplace = True)
filtered_df.drop(period_values, inplace = True)
filtered_df.drop(LT_values, inplace = True)
filtered_df.drop(LE_values, inplace = True)
filtered_df.drop(GT_values, inplace = True)
filtered_df.drop(GE_values, inplace = True)
filtered_df.info()

# %%
sns.kdeplot(cleaned_df)
# Out:
# C:\Anaconda3\envs\capstone\lib\site-packages\seaborn\distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.
