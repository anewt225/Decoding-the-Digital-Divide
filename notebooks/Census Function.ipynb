# %% [markdown]
# # Get Data Notebook
# This notebook us used to create functions for reproducibility of getting and combining data from Census and NCES

# %% [markdown]
# # Module Imports

# %%
## Import modules necessary for getting data from API and http:

import pandas as pd #standard
import numpy as np #standard
import matplotlib.pyplot as plt #for visualization
import seaborn as sns #for visualization
import requests #for APIs
import json #for APIS

# %% [markdown]
# # Variable Definitions

# %% [markdown]
# Here, we define several variables to simplify the reproduction of calling this API.

# %%
## Get list of state codes from census website

state_list = pd.read_csv("https://www2.census.gov/geo/docs/reference/state.txt", sep="|")
state_list = pd.DataFrame(state_list[["STATE","STUSAB","STATE_NAME"]])
state_list.columns = map(str.lower, state_list.columns)
state_list.state = state_list.state.apply(str)
state_list.state = state_list.state.str.zfill(2)
state_list = state_list[:51]

# %%
group_list = ['DP02', 'DP03', 'DP04', 'DP05']
year_list = ['2013', '2014', '2015', '2016', '2017', '2018']
geo_list = ['school%20district%20(unified)', 'school%20district%20(elementary)', 'school%20district%20(secondary)']
my_key = input('Input Personal Census API Key')
# Out:
# Input Personal Census API Key 2b07e25a69e507e080faa2c31f9da3b42d178b4e

# %% [markdown]
# # Download Data
#
# ## Census Data
# The function below is designed to iterate over the variables documented above. This will return what the Census calls "Data Profiles" for each state.

# %%
## Function to call Census API

# Loop over variables defined
for year in year_list:
    year = str(year)

    
    for group in group_list:
        group = str(group)

        geo = 'school%20district%20(unified)'


        group_states_info = []
        for state in state_list['state']:  
            state = str(state)

            get_acs_data = requests.get('https://api.census.gov/data/{year}/acs/acs5/profile?get=group({group})&for={geo}:*&in=state:{stateID}&key={key}'
                                        .format(year=year, group=group, geo=geo, stateID=state, key=my_key))
            acs_content = json.loads(get_acs_data.content)
            state_census_info = pd.DataFrame(data=acs_content)
            state_census_info.columns = state_census_info.iloc[0]
            state_census_info = state_census_info[1:]
            state_census_info['GEO_ID'] = state_census_info['GEO_ID'].str.lstrip('9700000US').str.zfill(7)
            state_census_info.rename(columns={'GEO_ID':'LEAID'}, inplace=True)
            group_states_info.append(state_census_info) 

        group_dp = pd.concat(group_states_info)
        group_dp.to_pickle('ACS_5yr_{group}_{year}.pkl'.format(group=group, year=year))
        print(group_dp.head)
# Out:
# <bound method NDFrame.head of 0     LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 1   0100001       1167        134        1167  -888888888        919
# 2   0100003        282         41         282  -888888888        255
# 3   0100005       7079        348        7079  -888888888       5020
# 4   0100006      17650        428       17650  -888888888      12944
# 5   0100007      32026        685       32026  -888888888      21939
# ..      ...        ...        ...         ...         ...        ...
# 45  5605820        362         75         362  -888888888        227
# 46  5605830       7583        445        7583  -888888888       4532
# 47  5606090        670        126         670  -888888888        431
# 48  5606240       3106        155        3106  -888888888       1970
# 49  5699997        225         87         225  -888888888         43
#
# 0  DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... DP02_0151EA DP02_0151MA  \
# 1         132        78.7         7.8        709  ...         (X)         (X)
# 2          37        90.4         7.3        208  ...         (X)         (X)
# 3         241        70.9         3.6       2467  ...         (X)         (X)
# 4         433        73.3         2.4       4924  ...         (X)         (X)
# 5         584        68.5         1.7      10752  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 45         54        62.7         9.0         50  ...         (X)         (X)
# 46        427        59.8         4.3       2071  ...         (X)         (X)
# 47         95        64.3        10.4        160  ...         (X)         (X)
# 48        169        63.4         4.5        872  ...         (X)         (X)
# 49         40        19.1        19.1         14  ...         (X)         (X)
#
# 0  DP02_0151PEA DP02_0151PMA DP02_0152EA DP02_0152MA DP02_0152PEA  \
# 1           (X)          (X)         (X)         (X)          (X)
# 2           (X)          (X)         (X)         (X)          (X)
# 3           (X)          (X)         (X)         (X)          (X)
# 4           (X)          (X)         (X)         (X)          (X)
# 5           (X)          (X)         (X)         (X)          (X)
# ..          ...          ...         ...         ...          ...
# 45          (X)          (X)         (X)         (X)          (X)
# 46          (X)          (X)         (X)         (X)          (X)
# 47          (X)          (X)         (X)         (X)          (X)
# 48          (X)          (X)         (X)         (X)          (X)
# 49          (X)          (X)         (X)         (X)          (X)
#
# 0  DP02_0152PMA state school district (unified)
# 1           (X)    01                     00001
# 2           (X)    01                     00003
# 3           (X)    01                     00005
# 4           (X)    01                     00006
# 5           (X)    01                     00007
# ..          ...   ...                       ...
# 45          (X)    56                     05820
# 46          (X)    56                     05830
# 47          (X)    56                     06090
# 48          (X)    56                     06240
# 49          (X)    56                     99997
#
# [10940 rows x 1220 columns]>
# <bound method NDFrame.head of 0     LEAID DP03_0001E DP03_0001M DP03_0001PE DP03_0001PM DP03_0002E  \
# 1   0100001       3136        291        3136  -888888888       2404
# 2   0100003       1763        208        1763  -888888888        812
# 3   0100005      15662        406       15662  -888888888       9993
# 4   0100006      37686        455       37686  -888888888      21507
# 5   0100007      63412        952       63412  -888888888      43958
# ..      ...        ...        ...         ...         ...        ...
# 45  5605820        660        136         660  -888888888        392
# 46  5605830      17894        214       17894  -888888888      14142
# 47  5606090       1258        210        1258  -888888888        888
# 48  5606240       5922        135        5922  -888888888       3823
# 49  5699997        425        191         425  -888888888        401
#
# 0  DP03_0002M DP03_0002PE DP03_0002PM DP03_0003E  ... DP03_0136EA DP03_0136MA  \
# 1         276        76.7         4.5        626  ...         (X)         (X)
# 2         122        46.1         5.5        204  ...         (X)         (X)
# 3         452        63.8         2.5       9993  ...         (X)         (X)
# 4         683        57.1         1.8      21507  ...         (X)         (X)
# 5        1149        69.3         1.4      43795  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 45        104        59.4         8.1        392  ...         (X)         (X)
# 46        431        79.0         2.4      14142  ...         (X)         (X)
# 47        166        70.6         5.6        888  ...         (X)         (X)
# 48        206        64.6         3.1       3823  ...         (X)         (X)
# 49        182        94.4         7.2        401  ...         (X)         (X)
#
# 0  DP03_0136PMA DP03_0136PEA DP03_0137MA DP03_0137EA DP03_0137PMA  \
# 1          None         None         (X)         (X)         None
# 2          None         None         (X)         (X)         None
# 3          None         None         (X)         (X)         None
# 4          None         None         (X)         (X)         None
# 5          None         None         (X)         (X)         None
# ..          ...          ...         ...         ...          ...
# 45         None         None         (X)         (X)         None
# 46         None         None         (X)         (X)         None
# 47         None         None         (X)         (X)         None
# 48         None         None         (X)         (X)         None
# 49         None         None         (X)         (X)         None
#
# 0  DP03_0137PEA state school district (unified)
# 1          None    01                     00001
# 2          None    01                     00003
# 3          None    01                     00005
# 4          None    01                     00006
# 5          None    01                     00007
# ..          ...   ...                       ...
# 45         None    56                     05820
# 46         None    56                     05830
# 47         None    56                     06090
# 48         None    56                     06240
# 49         None    56                     99997
#
# [10940 rows x 1100 columns]>
# <bound method NDFrame.head of 0  DP04_0117M   DP04_0117PE   DP04_0117PM DP04_0118E DP04_0118M   DP04_0118PE  \
# 1          11  -666666666.0  -222222222.0          0         11  -666666666.0
# 2          11  -666666666.0  -222222222.0          0         11  -666666666.0
# 3          86          15.1           5.6        200         91          13.6
# 4         280          22.2           3.8        772        172          12.2
# 5         176          20.2           3.5        361        119           7.0
# ..        ...           ...           ...        ...        ...           ...
# 45         22          22.1          11.5         13         12           8.4
# 46         75          11.3           5.2        205        119          13.1
# 47         27          22.3          10.3         25         16          10.5
# 48         56          16.0           6.4        113         51          13.3
# 49         11  -666666666.0  -222222222.0          0         11  -666666666.0
#
# 0    DP04_0118PM DP04_0119E DP04_0119M   DP04_0119PE  ... DP04_0115MA  \
# 1   -222222222.0          0         11  -666666666.0  ...        None
# 2   -222222222.0          0         11  -666666666.0  ...        None
# 3            5.8        168         91          11.4  ...        None
# 4            2.6        517        122           8.2  ...        None
# 5            2.2        357        143           6.9  ...        None
# ..           ...        ...        ...           ...  ...         ...
# 45           7.7         20         15          13.0  ...        None
# 46           7.1         96         90           6.1  ...        None
# 47           6.2          6          6           2.5  ...        None
# 48           6.2         69         45           8.1  ...        None
# 49  -222222222.0          0         11  -666666666.0  ...        None
#
# 0  DP04_0115PEA DP04_0115PMA DP04_0116EA DP04_0116MA DP04_0116PMA  \
# 1          None          (X)        None        None           **
# 2          None          (X)        None        None           **
# 3          None          (X)        None        None         None
# 4          None          (X)        None        None         None
# 5          None          (X)        None        None         None
# ..          ...          ...         ...         ...          ...
# 45         None          (X)        None        None         None
# 46         None          (X)        None        None         None
# 47         None          (X)        None        None         None
# 48         None          (X)        None        None         None
# 49         None          (X)        None        None           **
#
# 0  DP04_0116PEA DP04_0117EA state school district (unified)
# 1             -        None    01                     00001
# 2             -        None    01                     00003
# 3          None        None    01                     00005
# 4          None        None    01                     00006
# 5          None        None    01                     00007
# ..          ...         ...   ...                       ...
# 45         None        None    56                     05820
# 46         None        None    56                     05830
# 47         None        None    56                     06090
# 48         None        None    56                     06240
# 49            -        None    56                     99997
#
# [10940 rows x 1132 columns]>
# <bound method NDFrame.head of 0     LEAID DP05_0001E  DP05_0001M DP05_0001PE DP05_0001PM DP05_0002E  \
# 1   0100001       4844         474        4844  -888888888       2766
# 2   0100003       2136         237        2136  -888888888       1544
# 3   0100005      21281          35       21281  -888888888      10852
# 4   0100006      47539          50       47539  -888888888      23825
# 5   0100007      82350         439       82350  -888888888      39426
# ..      ...        ...         ...         ...         ...        ...
# 45  5605820        751         166         751  -888888888        389
# 46  5605830      21575  -555555555       21575  -888888888      11316
# 47  5606090       1488         270        1488  -888888888        781
# 48  5606240       7717         166        7717  -888888888       3865
# 49  5699997        462         209         462  -888888888        306
#
# 0  DP05_0002M DP05_0002PE DP05_0002PM DP05_0003E  ... DP05_0080MA DP05_0080EA  \
# 1         290        57.1         3.5       2078  ...        None        None
# 2         191        72.3         4.1        592  ...        None        None
# 3         370        51.0         1.8      10429  ...        None        None
# 4         408        50.1         0.9      23714  ...        None        None
# 5         933        47.9         1.1      42924  ...        None        None
# ..        ...         ...         ...        ...  ...         ...         ...
# 45        100        51.8         5.6        362  ...        None        None
# 46        243        52.4         1.1      10259  ...        None        None
# 47        156        52.5         4.1        707  ...        None        None
# 48        131        50.1         1.2       3852  ...        None        None
# 49        191        66.2        20.3        156  ...        None        None
#
# 0  DP05_0080PEA DP05_0080PMA DP05_0081EA DP05_0081MA DP05_0081PEA  \
# 1          None         None        None        None          (X)
# 2          None         None        None        None          (X)
# 3          None         None        None        None          (X)
# 4          None         None        None        None          (X)
# 5          None         None        None        None          (X)
# ..          ...          ...         ...         ...          ...
# 45         None         None        None        None          (X)
# 46         None         None        None        None          (X)
# 47         None         None        None        None          (X)
# 48         None         None        None        None          (X)
# 49         None         None        None        None          (X)
#
# 0  DP05_0081PMA state school district (unified)
# 1           (X)    01                     00001
# 2           (X)    01                     00003
# 3           (X)    01                     00005
# 4           (X)    01                     00006
# 5           (X)    01                     00007
# ..          ...   ...                       ...
# 45          (X)    56                     05820
# 46          (X)    56                     05830
# 47          (X)    56                     06090
# 48          (X)    56                     06240
# 49          (X)    56                     99997
#
# [10940 rows x 652 columns]>
# <bound method NDFrame.head of 0     LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 1   0103000       3918        204        3918  -888888888       2429
# 2   0103030      53771        565       53771  -888888888      38455
# 3   0103062      19887        546       19887  -888888888      14654
# 4   0103090       4962        245        4962  -888888888       3039
# 5   0103120       5078        266        5078  -888888888       3473
# ..      ...        ...        ...         ...         ...        ...
# 44  5604230       1024         99        1024  -888888888        581
# 45  5604260       1170        147        1170  -888888888        757
# 46  5604380        371         67         371  -888888888        231
# 47  5604450        579         63         579  -888888888        465
# 48  5604500       1258        156        1258  -888888888        932
#
# 0  DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... DP02_0151MA DP02_0151EA  \
# 1         145        62.0         4.3        841  ...         (X)         (X)
# 2         667        71.5         1.2      17738  ...         (X)         (X)
# 3         553        73.7         2.2       6123  ...         (X)         (X)
# 4         238        61.2         3.9       1139  ...         (X)         (X)
# 5         192        68.4         3.1       1641  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 44         78        56.7         7.0        207  ...         (X)         (X)
# 45        111        64.7         9.1        316  ...         (X)         (X)
# 46         59        62.3        10.4         77  ...         (X)         (X)
# 47         57        80.3         5.0        179  ...         (X)         (X)
# 48        147        74.1         8.8        463  ...         (X)         (X)
#
# 0  DP02_0151PMA DP02_0151PEA DP02_0152EA DP02_0152MA DP02_0152PEA  \
# 1           (X)          (X)         (X)         (X)          (X)
# 2           (X)          (X)         (X)         (X)          (X)
# 3           (X)          (X)         (X)         (X)          (X)
# 4           (X)          (X)         (X)         (X)          (X)
# 5           (X)          (X)         (X)         (X)          (X)
# ..          ...          ...         ...         ...          ...
# 44          (X)          (X)         (X)         (X)          (X)
# 45          (X)          (X)         (X)         (X)          (X)
# 46          (X)          (X)         (X)         (X)          (X)
# 47          (X)          (X)         (X)         (X)          (X)
# 48          (X)          (X)         (X)         (X)          (X)
#
# 0  DP02_0152PMA state school district (unified)
# 1           (X)    01                     03000
# 2           (X)    01                     03030
# 3           (X)    01                     03062
# 4           (X)    01                     03090
# 5           (X)    01                     03120
# ..          ...   ...                       ...
# 44          (X)    56                     04230
# 45          (X)    56                     04260
# 46          (X)    56                     04380
# 47          (X)    56                     04450
# 48          (X)    56                     04500
#
# [10922 rows x 1220 columns]>
# <bound method NDFrame.head of 0     LEAID DP03_0001E DP03_0001M DP03_0001PE DP03_0001PM DP03_0002E  \
# 1   0103000       7493        264        7493  -888888888       4015
# 2   0103030     112724        737      112724  -888888888      76973
# 3   0103062      43521        818       43521  -888888888      26068
# 4   0103090      10935         63       10935  -888888888       5624
# 5   0103120       9849        263        9849  -888888888       5341
# ..      ...        ...        ...         ...         ...        ...
# 44  5604230       2113         76        2113  -888888888       1235
# 45  5604260       2379        259        2379  -888888888       1609
# 46  5604380        665        139         665  -888888888        418
# 47  5604450       1748        191        1748  -888888888       1125
# 48  5604500       2578        330        2578  -888888888       1875
#
# 0  DP03_0002M DP03_0002PE DP03_0002PM DP03_0003E  ... DP03_0136EA DP03_0136MA  \
# 1         278        53.6         3.7       3991  ...         (X)         (X)
# 2         964        68.3         0.8      76901  ...         (X)         (X)
# 3         962        59.9         1.8      25985  ...         (X)         (X)
# 4         367        51.4         3.3       5623  ...         (X)         (X)
# 5         321        54.2         3.1       5341  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 44        128        58.4         5.9       1224  ...         (X)         (X)
# 45        230        67.6         5.1       1609  ...         (X)         (X)
# 46         93        62.9         6.7        418  ...         (X)         (X)
# 47        141        64.4         4.2       1125  ...         (X)         (X)
# 48        319        72.7         8.0       1875  ...         (X)         (X)
#
# 0  DP03_0136PEA DP03_0136PMA DP03_0137EA DP03_0137MA DP03_0137PMA  \
# 1          None         None         (X)         (X)         None
# 2          None         None         (X)         (X)         None
# 3          None         None         (X)         (X)         None
# 4          None         None         (X)         (X)         None
# 5          None         None         (X)         (X)         None
# ..          ...          ...         ...         ...          ...
# 44         None         None         (X)         (X)         None
# 45         None         None         (X)         (X)         None
# 46         None         None         (X)         (X)         None
# 47         None         None         (X)         (X)         None
# 48         None         None         (X)         (X)         None
#
# 0  DP03_0137PEA state school district (unified)
# 1          None    01                     03000
# 2          None    01                     03030
# 3          None    01                     03062
# 4          None    01                     03090
# 5          None    01                     03120
# ..          ...   ...                       ...
# 44         None    56                     04230
# 45         None    56                     04260
# 46         None    56                     04380
# 47         None    56                     04450
# 48         None    56                     04500
#
# [10922 rows x 1100 columns]>
# <bound method NDFrame.head of 0  DP04_0023M DP04_0023PE DP04_0023PM DP04_0024E DP04_0024M DP04_0024PE  \
# 1         162        21.9         3.3        452         99         9.7
# 2         307         3.4         0.5        636        161         1.1
# 3         228         5.6         1.0        478        152         2.2
# 4         146         7.8         2.1        311        121         4.6
# 5         156        14.0         2.7        775        169        13.2
# ..        ...         ...         ...        ...        ...         ...
# 44         60        12.0         4.2        182         55        13.7
# 45         26         2.8         2.0         17         17         1.3
# 46         18         6.2         3.7         66         33        13.3
# 47         20         5.6         3.1         11         10         1.7
# 48         35         4.7         2.5         18         17         1.3
#
# 0  DP04_0024PM DP04_0025E DP04_0025M DP04_0025PE  ... DP04_0140EA DP04_0140MA  \
# 1          2.1        761        137        16.4  ...        None        None
# 2          0.3       1164        200         2.0  ...        None        None
# 3          0.7        772        259         3.5  ...        None        None
# 4          1.8        369         93         5.5  ...        None        None
# 5          2.6        569        169         9.7  ...        None        None
# ..         ...        ...        ...         ...  ...         ...         ...
# 44         4.0        482         82        36.4  ...        None        None
# 45         1.3        155        104        12.0  ...        None        None
# 46         6.2        107         39        21.5  ...        None        None
# 47         1.5         33         17         5.1  ...        None        None
# 48         1.2        117         70         8.2  ...        None        None
#
# 0  DP04_0140PMA DP04_0140PEA DP04_0141EA DP04_0141MA DP04_0141PMA  \
# 1          None         None        None        None          (X)
# 2          None         None        None        None          (X)
# 3          None         None        None        None          (X)
# 4          None         None        None        None          (X)
# 5          None         None        None        None          (X)
# ..          ...          ...         ...         ...          ...
# 44         None         None        None        None          (X)
# 45         None         None        None        None          (X)
# 46         None         None        None        None          (X)
# 47         None         None        None        None          (X)
# 48         None         None        None        None          (X)
#
# 0  DP04_0141PEA state school district (unified)
# 1           (X)    01                     03000
# 2           (X)    01                     03030
# 3           (X)    01                     03062
# 4           (X)    01                     03090
# 5           (X)    01                     03120
# ..          ...   ...                       ...
# 44          (X)    56                     04230
# 45          (X)    56                     04260
# 46          (X)    56                     04380
# 47          (X)    56                     04450
# 48          (X)    56                     04500
#
# [10922 rows x 1132 columns]>
# <bound method NDFrame.head of 0   DP05_0024M DP05_0024PE   DP05_0024PM DP05_0025E  DP05_0025M DP05_0025PE  \
# 1          240        55.0           2.6       1593         160        1593
# 2          509        51.8           0.4      16278         457       16278
# 3          481        49.3           0.8       7059         348        7059
# 4   -555555555        55.9  -888888888.0       2082  -555555555        2082
# 5          235        54.5           2.2       2130         246        2130
# ..         ...         ...           ...        ...         ...         ...
# 44          81        56.6           3.3        468          90         468
# 45         125        45.5           3.7        264          88         264
# 46          64        46.8           4.5        168          57         168
# 47         106        52.6           3.2        166          43         166
# 48         146        46.6           3.4        396         128         396
#
# 0  DP05_0025PM DP05_0026E  DP05_0026M DP05_0026PE  ... DP05_0022MA  \
# 1   -888888888        592          90        37.2  ...        None
# 2   -888888888       7338         252        45.1  ...        None
# 3   -888888888       3172         234        44.9  ...        None
# 4   -888888888        793  -555555555        38.1  ...       *****
# 5   -888888888        864         144        40.6  ...        None
# ..         ...        ...         ...         ...  ...         ...
# 44  -888888888        231          55        49.4  ...        None
# 45  -888888888        136          50        51.5  ...        None
# 46  -888888888         92          32        54.8  ...        None
# 47  -888888888         75          31        45.2  ...        None
# 48  -888888888        170          70        42.9  ...        None
#
# 0  DP05_0022PMA DP05_0022PEA DP05_0023EA DP05_0023MA DP05_0023PEA  \
# 1           (X)         None        None        None         None
# 2           (X)         None        None        None         None
# 3           (X)         None        None        None         None
# 4           (X)         None        None       *****         None
# 5           (X)         None        None        None         None
# ..          ...          ...         ...         ...          ...
# 44          (X)         None        None        None         None
# 45          (X)         None        None        None         None
# 46          (X)         None        None        None         None
# 47          (X)         None        None        None         None
# 48          (X)         None        None        None         None
#
# 0  DP05_0023PMA DP05_0024EA state school district (unified)
# 1          None        None    01                     03000
# 2          None        None    01                     03030
# 3          None        None    01                     03062
# 4         *****        None    01                     03090
# 5          None        None    01                     03120
# ..          ...         ...   ...                       ...
# 44         None        None    56                     04230
# 45         None        None    56                     04260
# 46         None        None    56                     04380
# 47         None        None    56                     04450
# 48         None        None    56                     04500
#
# [10922 rows x 652 columns]>
# <bound method NDFrame.head of 0     LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 1   0100001       1230        163        1230  -888888888        927
# 2   0100003        279         37         279  -888888888        249
# 3   0100005       7307        287        7307  -888888888       5183
# 4   0100006      17541        490       17541  -888888888      12942
# 5   0100007      32550        577       32550  -888888888      22299
# ..      ...        ...        ...         ...         ...        ...
# 44  5605820        311         54         311  -888888888        192
# 45  5605830       8187        412        8187  -888888888       4840
# 46  5606090        667        134         667  -888888888        355
# 47  5606240       3201        126        3201  -888888888       2041
# 48  5699999        509        112         509  -888888888        340
#
# 0  DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... DP02_0151EA DP02_0151MA  \
# 1         148        75.4         8.6        702  ...         (X)         (X)
# 2          34        89.2         6.0        196  ...         (X)         (X)
# 3         265        70.9         3.7       2584  ...         (X)         (X)
# 4         417        73.8         2.5       4809  ...         (X)         (X)
# 5         426        68.5         1.5      10551  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 44         39        61.7         8.2         55  ...         (X)         (X)
# 45        414        59.1         4.4       2075  ...         (X)         (X)
# 46         81        53.2        10.2         86  ...         (X)         (X)
# 47        152        63.8         4.2        916  ...         (X)         (X)
# 48         40        66.8        14.3        151  ...         (X)         (X)
#
# 0  DP02_0151PMA DP02_0151PEA DP02_0152EA DP02_0152MA DP02_0152PMA  \
# 1           (X)          (X)         (X)         (X)          (X)
# 2           (X)          (X)         (X)         (X)          (X)
# 3           (X)          (X)         (X)         (X)          (X)
# 4           (X)          (X)         (X)         (X)          (X)
# 5           (X)          (X)         (X)         (X)          (X)
# ..          ...          ...         ...         ...          ...
# 44          (X)          (X)         (X)         (X)          (X)
# 45          (X)          (X)         (X)         (X)          (X)
# 46          (X)          (X)         (X)         (X)          (X)
# 47          (X)          (X)         (X)         (X)          (X)
# 48          (X)          (X)         (X)         (X)          (X)
#
# 0  DP02_0152PEA state school district (unified)
# 1           (X)    01                     00001
# 2           (X)    01                     00003
# 3           (X)    01                     00005
# 4           (X)    01                     00006
# 5           (X)    01                     00007
# ..          ...   ...                       ...
# 44          (X)    56                     05820
# 45          (X)    56                     05830
# 46          (X)    56                     06090
# 47          (X)    56                     06240
# 48          (X)    56                     99999
#
# [10922 rows x 1220 columns]>
# <bound method NDFrame.head of 0     LEAID DP03_0001E DP03_0001M DP03_0001PE DP03_0001PM DP03_0002E  \
# 1   0100001       3180        321        3180  -888888888       2435
# 2   0100003       1824        172        1824  -888888888        915
# 3   0100005      15703        378       15703  -888888888       9289
# 4   0100006      38045        432       38045  -888888888      21352
# 5   0100007      64416        698       64416  -888888888      44974
# ..      ...        ...        ...         ...         ...        ...
# 44  5605820        590        106         590  -888888888        336
# 45  5605830      18682        126       18682  -888888888      14681
# 46  5606090       1264        218        1264  -888888888        834
# 47  5606240       6042        119        6042  -888888888       3840
# 48  5699999       1439        286        1439  -888888888        989
#
# 0  DP03_0002M DP03_0002PE DP03_0002PM DP03_0003E  ... DP03_0136EA DP03_0136MA  \
# 1         274        76.6         4.3        619  ...         (X)         (X)
# 2         139        50.2         6.1        224  ...         (X)         (X)
# 3         476        59.2         2.9       9289  ...         (X)         (X)
# 4         689        56.1         1.8      21352  ...         (X)         (X)
# 5         869        69.8         1.4      44845  ...         (X)         (X)
# ..        ...         ...         ...        ...  ...         ...         ...
# 44         74        56.9         6.6        336  ...         (X)         (X)
# 45        443        78.6         2.4      14681  ...         (X)         (X)
# 46        178        66.0         6.7        834  ...         (X)         (X)
# 47        206        63.6         3.2       3840  ...         (X)         (X)
# 48        260        68.7         5.9        989  ...         (X)         (X)
#
# 0  DP03_0136PMA DP03_0136PEA DP03_0137MA DP03_0137EA DP03_0137PMA  \
# 1          None         None         (X)         (X)         None
# 2          None         None         (X)         (X)         None
# 3          None         None         (X)         (X)         None
# 4          None         None         (X)         (X)         None
# 5          None         None         (X)         (X)         None
# ..          ...          ...         ...         ...          ...
# 44         None         None         (X)         (X)         None
# 45         None         None         (X)         (X)         None
# 46         None         None         (X)         (X)         None
# 47         None         None         (X)         (X)         None
# 48         None         None         (X)         (X)         None
#
# 0  DP03_0137PEA state school district (unified)
# 1          None    01                     00001
# 2          None    01                     00003
# 3          None    01                     00005
# 4          None    01                     00006
# 5          None    01                     00007
# ..          ...   ...                       ...
# 44         None    56                     05820
# 45         None    56                     05830
# 46         None    56                     06090
# 47         None    56                     06240
# 48         None    56                     99999
#
# [10922 rows x 1100 columns]>
# <bound method NDFrame.head of 0     LEAID DP04_0001E DP04_0001M DP04_0001PE DP04_0001PM DP04_0002E  \
# 1   0100001       1524        109        1524  -888888888       1230
# 2   0100003        291         38         291  -888888888        279
# 3   0100005       8121        333        8121  -888888888       7307
# 4   0100006      21337        383       21337  -888888888      17541
# 5   0100007      35214        607       35214  -888888888      32550
# ..      ...        ...        ...         ...         ...        ...
# 44  5605820        412         65         412  -888888888        311
# 45  5605830      13146         58       13146  -888888888       8187
# 46  5606090        868        134         868  -888888888        667
# 47  5606240       3407         73        3407  -888888888       3201
# 48  5699999        708        128         708  -888888888        509
#
# 0  DP04_0002M DP04_0002PE DP04_0002PM DP04_0003E  ... DP04_0142MA DP04_0142EA  \
# 1         163        80.7         8.5        294  ...        None        None
# 2          37        95.9         3.8         12  ...        None        None
# 3         287        90.0         2.8        814  ...        None        None
# 4         490        82.2         2.1       3796  ...        None        None
# 5         577        92.4         1.3       2664  ...        None        None
# ..        ...         ...         ...        ...  ...         ...         ...
# 44         54        75.5         6.9        101  ...        None        None
# 45        412        62.3         3.1       4959  ...        None        None
# 46        134        76.8         7.7        201  ...        None        None
# 47        126        94.0         3.2        206  ...        None        None
# 48        112        71.9        11.2        199  ...        None        None
#
# 0  DP04_0142PEA DP04_0142PMA DP04_0143MA DP04_0143EA DP04_0143PEA  \
# 1          None         None        None        None          (X)
# 2          None         None        None        None          (X)
# 3          None         None        None        None          (X)
# 4          None         None        None        None          (X)
# 5          None         None        None        None          (X)
# ..          ...          ...         ...         ...          ...
# 44         None         None        None        None          (X)
# 45         None         None        None        None          (X)
# 46         None         None        None        None          (X)
# 47         None         None        None        None          (X)
# 48         None         None        None        None          (X)
#
# 0  DP04_0143PMA state school district (unified)
# 1           (X)    01                     00001
# 2           (X)    01                     00003
# 3           (X)    01                     00005
# 4           (X)    01                     00006
# 5           (X)    01                     00007
# ..          ...   ...                       ...
# 44          (X)    56                     05820
# 45          (X)    56                     05830
# 46          (X)    56                     06090
# 47          (X)    56                     06240
# 48          (X)    56                     99999
#
# [10922 rows x 1148 columns]>
# <bound method NDFrame.head of 0  DP05_0070PE DP05_0070PM DP05_0071E  DP05_0071M DP05_0071PE   DP05_0071PM  \
# 1          1.1         1.3       4117         404        84.1           5.7
# 2          2.1         1.3       1972         206        88.4           2.9
# 3          6.2         2.2      15853         675        74.1           3.1
# 4          1.4         0.8      43707         694        91.4           1.4
# 5          0.9         0.4      78040        1119        94.0           1.2
# ..         ...         ...        ...         ...         ...           ...
# 44         0.6         0.8        688         135        99.0           1.2
# 45         2.3         1.5      18933  -555555555        84.9  -888888888.0
# 46         1.8         3.6       1379         236        97.4           3.4
# 47         0.6         0.5       6537         135        84.8           0.3
# 48         1.1         1.5       1832         278        92.2           4.1
#
# 0  DP05_0072E DP05_0072M DP05_0072PE DP05_0072PM  ... DP05_0068PEA  \
# 1        3408        392        69.6         6.3  ...         None
# 2        1331        145        59.7         4.6  ...         None
# 3       15053        703        70.3         3.3  ...         None
# 4       42219        722        88.3         1.5  ...         None
# 5       58767       1329        70.8         1.6  ...         None
# ..        ...        ...         ...         ...  ...          ...
# 44        668        130        96.1         2.5  ...         None
# 45      18115         15        81.2         0.1  ...         None
# 46       1294        231        91.4         7.0  ...         None
# 47       6253        150        81.2         0.9  ...         None
# 48        498        241        25.1         9.6  ...         None
#
# 0  DP05_0068PMA DP05_0069MA DP05_0069EA DP05_0069PMA DP05_0069PEA DP05_0070MA  \
# 1          None        None        None         None         None        None
# 2          None        None        None         None         None        None
# 3          None        None        None         None         None        None
# 4          None        None        None         None         None        None
# 5          None        None        None         None         None        None
# ..          ...         ...         ...          ...          ...         ...
# 44         None        None        None         None         None        None
# 45         None        None        None         None         None        None
# 46         None        None        None         None         None        None
# 47         None        None        None         None         None        None
# 48         None        None        None         None         None        None
#
# 0  DP05_0070EA state school district (unified)
# 1         None    01                     00001
# 2         None    01                     00003
# 3         None    01                     00005
# 4         None    01                     00006
# 5         None    01                     00007
# ..         ...   ...                       ...
# 44        None    56                     05820
# 45        None    56                     05830
# 46        None    56                     06090
# 47        None    56                     06240
# 48        None    56                     99999
#
# [10922 rows x 676 columns]>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'GEO_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-04b5ffca2de9> in <module>
#      19             state_census_info.columns = state_census_info.iloc[0]
#      20             state_census_info = state_census_info[1:]
# ---> 21             state_census_info['GEO_ID'] = state_census_info['GEO_ID'].str.lstrip('9700000US').str.zfill(7)
#      22             state_census_info.rename(columns={'GEO_ID':'LEAID'}, inplace=True)
#      23             group_states_info.append(state_census_info)
#
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'GEO_ID'

# %% [markdown]
# # Import Educational Data

# %%
## Create new variables for each file created
## Merge datasets together

dp02 = pd.read_pickle('ACS_5yr_DP02_2018.pkl')
dp03 = pd.read_pickle('ACS_5yr_DP03_2018.pkl')
dp04 = pd.read_pickle('ACS_5yr_DP04_2018.pkl')
dp05 = pd.read_pickle('ACS_5yr_DP05_2018.pkl')
ACS_2018A = pd.merge(dp02, dp03, on='LEAID', how='inner')
ACS_2018B = pd.merge(dp04, dp05, on='LEAID', how='inner')
ACS_2018 = pd.merge(ACS_2018A, ACS_2018B, on='LEAID', how='inner')
ACS_2018.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-63f610232760> in <module>
#       4 dp02 = pd.read_pickle('ACS_5yr_DP02_2018.pkl')
#       5 dp03 = pd.read_pickle('ACS_5yr_DP03_2018.pkl')
# ----> 6 dp04 = pd.read_pickle('ACS_5yr_DP04_2018.pkl')
#       7 dp05 = pd.read_pickle('ACS_5yr_DP05_2018.pkl')
#       8 ACS_2018A = pd.merge(dp02, dp03, on='LEAID', how='inner')
#
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression)
#     180                 # We want to silence any warnings about, e.g. moved modules.
#     181                 warnings.simplefilter("ignore", Warning)
# --> 182                 return pickle.load(f)
#     183         except excs_to_catch:
#     184             # e.g.
#
# C:\Anaconda3\envs\capstone\lib\site-packages\pandas\core\indexes\base.py in _new_Index(cls, d)
#     168
#     169
# --> 170 def _new_Index(cls, d):
#     171     """
#     172     This is called upon unpickling, rather than the default which doesn't
#
# KeyboardInterrupt:

# %%
## Save this file to a pickle for later reference / calling
ACS_2018.to_pickle('../data/acs_2018.pkl')
ACS_2018.head()
# Out:
# 0    LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 0  0102650      11557        430       11557  -888888888       7879
# 1  0102670       3079        238        3079  -888888888       1588
# 2  0102700      14462        421       14462  -888888888       8813
# 3  0102730       7530        262        7530  -888888888       4935
# 4  0102760       2671        205        2671  -888888888       1839
#
# 0 DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... DP05_0029PEA DP05_0030MA  \
# 0        368        68.2         3.4       2803  ...         None        None
# 1        256        51.6         7.8        451  ...         None       *****
# 2        424        60.9         3.1       4413  ...         None        None
# 3        279        65.5         3.1       1688  ...         None        None
# 4        167        68.9         4.6        726  ...         None        None
#
# 0 DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA DP05_0031EA DP05_0031PEA  \
# 0        None         None         None        None        None         None
# 1        None        *****         None       *****        None         None
# 2        None         None         None        None        None         None
# 3        None         None         None        None        None         None
# 4        None         None         None        None        None         None
#
# 0 state_y_y school district (unified)_y_y
# 0        01                         02650
# 1        01                         02670
# 2        01                         02700
# 3        01                         02730
# 4        01                         02760
#
# [5 rows x 4181 columns]

# %%
## Read pickle for assessment
## Change column to LEAID for later

assessment_2018 = pd.read_pickle('../data/assessment_2018.pkl')
assessment_2018.rename(columns={'leaid':'LEAID'}, inplace=True)
assessment_2018.head()
# Out:
#    STNAM_x  FIPST_x    LEAID ST_LEAID_x           LEANM_x DATE_CUR_x  \
# 0  ALABAMA        1  0100005     AL-101  Albertville City    27MAR19
# 1  ALABAMA        1  0100006     AL-048   Marshall County    27MAR19
# 2  ALABAMA        1  0100007     AL-158       Hoover City    27MAR19
# 3  ALABAMA        1  0100008     AL-169      Madison City    27MAR19
# 4  ALABAMA        1  0100011     AL-167        Leeds City    27MAR19
#
#    ALL_MTH00NUMVALID_1718 ALL_MTH00PCTPROF_1718 MAM_MTH00NUMVALID_1718  \
# 0                    2892                    45                      5
# 1                    2987                    43                     12
# 2                    7551                    70                      5
# 3                    5668                    76                     47
# 4                    1017                    40                      2
#
#   MAM_MTH00PCTPROF_1718  ... MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718  \
# 0                    PS  ...                     14                  LT50
# 1                  GE50  ...                      1                    PS
# 2                    PS  ...                     11                  GE50
# 3                 60-69  ...                     34                 80-89
# 4                    PS  ...                      6                  LT50
#
#   MIL_RLA06NUMVALID_1718 MIL_RLA06PCTPROF_1718 MIL_RLA07NUMVALID_1718  \
# 0                      5                    PS                     11
# 1                    NaN                   NaN                      3
# 2                      8                  GE50                      6
# 3                     38                 70-79                     42
# 4                    NaN                   NaN                      2
#
#   MIL_RLA07PCTPROF_1718 MIL_RLA08NUMVALID_1718 MIL_RLA08PCTPROF_1718  \
# 0                  GE50                     14                  GE50
# 1                    PS                      2                    PS
# 2                  GE50                     12                  GE50
# 3                 70-79                     51                 70-79
# 4                    PS                      4                    PS
#
#   MIL_RLAHSNUMVALID_1718 MIL_RLAHSPCTPROF_1718
# 0                     10                  GE50
# 1                      3                    PS
# 2                     20                 40-59
# 3                     44                 60-69
# 4                      3                    PS
#
# [5 rows x 523 columns]

# %%
## Set the index for using LEAID as the LEAID, since it doesn't tell anything specifically
assessment_2018.set_index('LEAID')
# Out:
#          STNAM_x  FIPST_x  ST_LEAID_x                               LEANM_x  \
# LEAID
# 0100005  ALABAMA        1      AL-101                      Albertville City
# 0100006  ALABAMA        1      AL-048                       Marshall County
# 0100007  ALABAMA        1      AL-158                           Hoover City
# 0100008  ALABAMA        1      AL-169                          Madison City
# 0100011  ALABAMA        1      AL-167                            Leeds City
# ...          ...      ...         ...                                   ...
# 5513770  WYOMING       56  WY-1902000  Sweetwater County School District #2
# 5513800  WYOMING       56  WY-2202000    Washakie County School District #2
# 5513830  WYOMING       56  WY-2001000       Teton County School District #1
# 5513860  WYOMING       56  WY-2307000      Weston County School District #7
# 5513890  WYOMING       56  WY-2201000    Washakie County School District #1
#
#         DATE_CUR_x  ALL_MTH00NUMVALID_1718 ALL_MTH00PCTPROF_1718  \
# LEAID
# 0100005    27MAR19                    2892                    45
# 0100006    27MAR19                    2987                    43
# 0100007    27MAR19                    7551                    70
# 0100008    27MAR19                    5668                    76
# 0100011    27MAR19                    1017                    40
# ...            ...                     ...                   ...
# 5513770    27MAR19                    1629                    56
# 5513800    27MAR19                      58                 60-69
# 5513830    27MAR19                    1773                    55
# 5513860    27MAR19                     145                 40-44
# 5513890    27MAR19                     818                    57
#
#         MAM_MTH00NUMVALID_1718 MAM_MTH00PCTPROF_1718 MAS_MTH00NUMVALID_1718  \
# LEAID
# 0100005                      5                    PS                     18
# 0100006                     12                  GE50                      9
# 0100007                      5                    PS                    531
# 0100008                     47                 60-69                    530
# 0100011                      2                    PS                      9
# ...                        ...                   ...                    ...
# 5513770                     10                  GE50                      5
# 5513800                      1                    PS                    NaN
# 5513830                      6                  LT50                     34
# 5513860                    NaN                   NaN                    NaN
# 5513890                      6                  LT50                      2
#
#          ... MIL_RLA05NUMVALID_1718 MIL_RLA05PCTPROF_1718  \
# LEAID    ...
# 0100005  ...                     14                  LT50
# 0100006  ...                      1                    PS
# 0100007  ...                     11                  GE50
# 0100008  ...                     34                 80-89
# 0100011  ...                      6                  LT50
# ...      ...                    ...                   ...
# 5513770  ...                    NaN                   NaN
# 5513800  ...                    NaN                   NaN
# 5513830  ...                    NaN                   NaN
# 5513860  ...                    NaN                   NaN
# 5513890  ...                    NaN                   NaN
#
#         MIL_RLA06NUMVALID_1718 MIL_RLA06PCTPROF_1718 MIL_RLA07NUMVALID_1718  \
# LEAID
# 0100005                      5                    PS                     11
# 0100006                    NaN                   NaN                      3
# 0100007                      8                  GE50                      6
# 0100008                     38                 70-79                     42
# 0100011                    NaN                   NaN                      2
# ...                        ...                   ...                    ...
# 5513770                    NaN                   NaN                    NaN
# 5513800                    NaN                   NaN                    NaN
# 5513830                    NaN                   NaN                    NaN
# 5513860                    NaN                   NaN                    NaN
# 5513890                    NaN                   NaN                    NaN
#
#         MIL_RLA07PCTPROF_1718 MIL_RLA08NUMVALID_1718 MIL_RLA08PCTPROF_1718  \
# LEAID
# 0100005                  GE50                     14                  GE50
# 0100006                    PS                      2                    PS
# 0100007                  GE50                     12                  GE50
# 0100008                 70-79                     51                 70-79
# 0100011                    PS                      4                    PS
# ...                       ...                    ...                   ...
# 5513770                   NaN                    NaN                   NaN
# 5513800                   NaN                    NaN                   NaN
# 5513830                   NaN                    NaN                   NaN
# 5513860                   NaN                    NaN                   NaN
# 5513890                   NaN                    NaN                   NaN
#
#         MIL_RLAHSNUMVALID_1718 MIL_RLAHSPCTPROF_1718
# LEAID
# 0100005                     10                  GE50
# 0100006                      3                    PS
# 0100007                     20                 40-59
# 0100008                     44                 60-69
# 0100011                      3                    PS
# ...                        ...                   ...
# 5513770                    NaN                   NaN
# 5513800                    NaN                   NaN
# 5513830                    NaN                   NaN
# 5513860                    NaN                   NaN
# 5513890                    NaN                   NaN
#
# [16034 rows x 522 columns]

# %%
poverty_2018 = pd.read_pickle('../data/poverty_2018.pkl')
poverty_2018.head()
# Out:
# 0       SAEPOVRAT5_17RV_PT
# LEAID
# 0100001               12.4
# 0100003               15.2
# 0100005               30.1
# 0100006               26.6
# 0100007                7.3

# %%
acs_5yr_2018 = pd.merge(ACS_2018, poverty_2018, on="LEAID", how="inner")
acs_5yr_2018.set_index('LEAID')
# Out:
# 0       DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E DP02_0002M  \
# LEAID
# 0102650      11557        430       11557  -888888888       7879        368
# 0102670       3079        238        3079  -888888888       1588        256
# 0102700      14462        421       14462  -888888888       8813        424
# 0102730       7530        262        7530  -888888888       4935        279
# 0102760       2671        205        2671  -888888888       1839        167
# ...            ...        ...         ...         ...        ...        ...
# 5605762       4852        230        4852  -888888888       3489        227
# 5605820        327         66         327  -888888888        221         48
# 5605830       9158        486        9158  -888888888       5305        452
# 5606090        698         96         698  -888888888        394         66
# 5606240       3095        150        3095  -888888888       2081        144
#
# 0       DP02_0002PE DP02_0002PM DP02_0003E DP02_0003M  ... DP05_0030MA  \
# LEAID                                                  ...
# 0102650        68.2         3.4       2803        335  ...        None
# 0102670        51.6         7.8        451        152  ...       *****
# 0102700        60.9         3.1       4413        399  ...        None
# 0102730        65.5         3.1       1688        199  ...        None
# 0102760        68.9         4.6        726        127  ...        None
# ...             ...         ...        ...        ...  ...         ...
# 5605762        71.9         3.3       1637        214  ...        None
# 5605820        67.6         9.6         77         27  ...        None
# 5605830        57.9         4.3       2254        366  ...        None
# 5606090        56.4         8.4        153         66  ...        None
# 5606240        67.2         4.5        818        120  ...        None
#
# 0       DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA DP05_0031EA  \
# LEAID
# 0102650        None         None         None        None        None
# 0102670        None        *****         None       *****        None
# 0102700        None         None         None        None        None
# 0102730        None         None         None        None        None
# 0102760        None         None         None        None        None
# ...             ...          ...          ...         ...         ...
# 5605762        None         None         None        None        None
# 5605820        None         None         None        None        None
# 5605830        None         None         None        None        None
# 5606090        None         None         None        None        None
# 5606240        None         None         None        None        None
#
# 0       DP05_0031PEA state_y_y school district (unified)_y_y  \
# LEAID
# 0102650         None        01                         02650
# 0102670         None        01                         02670
# 0102700         None        01                         02700
# 0102730         None        01                         02730
# 0102760         None        01                         02760
# ...              ...       ...                           ...
# 5605762         None        56                         05762
# 5605820         None        56                         05820
# 5605830         None        56                         05830
# 5606090         None        56                         06090
# 5606240         None        56                         06240
#
# 0       SAEPOVRAT5_17RV_PT
# LEAID
# 0102650               16.5
# 0102670                 49
# 0102700               32.3
# 0102730               29.4
# 0102760               27.9
# ...                    ...
# 5605762                7.7
# 5605820                8.9
# 5605830                5.8
# 5606090                5.9
# 5606240               14.1
#
# [10733 rows x 4181 columns]

# %%
complete_df = pd.merge(acs_5yr_2018, assessment_2018, on='LEAID', how='inner')
complete_df.to_pickle('../data/complete_df.pkl')
complete_df.head()
# Out:
#      LEAID DP02_0001E DP02_0001M DP02_0001PE DP02_0001PM DP02_0002E  \
# 0  0102650      11557        430       11557  -888888888       7879
# 1  0102670       3079        238        3079  -888888888       1588
# 2  0102700      14462        421       14462  -888888888       8813
# 3  0102730       7530        262        7530  -888888888       4935
# 4  0102760       2671        205        2671  -888888888       1839
#
#   DP02_0002M DP02_0002PE DP02_0002PM DP02_0003E  ... MIL_RLA05NUMVALID_1718  \
# 0        368        68.2         3.4       2803  ...                      4
# 1        256        51.6         7.8        451  ...                      1
# 2        424        60.9         3.1       4413  ...                     10
# 3        279        65.5         3.1       1688  ...                    NaN
# 4        167        68.9         4.6        726  ...                    NaN
#
#   MIL_RLA05PCTPROF_1718 MIL_RLA06NUMVALID_1718 MIL_RLA06PCTPROF_1718  \
# 0                    PS                      2                    PS
# 1                    PS                      1                    PS
# 2                  GE50                      9                  LT50
# 3                   NaN                      2                    PS
# 4                   NaN                    NaN                   NaN
#
#   MIL_RLA07NUMVALID_1718 MIL_RLA07PCTPROF_1718 MIL_RLA08NUMVALID_1718  \
# 0                      1                    PS                      4
# 1                    NaN                   NaN                      1
# 2                      8                  GE50                      2
# 3                      4                    PS                      4
# 4                    NaN                   NaN                    NaN
#
#   MIL_RLA08PCTPROF_1718 MIL_RLAHSNUMVALID_1718 MIL_RLAHSPCTPROF_1718
# 0                    PS                      0                   NaN
# 1                    PS                      1                    PS
# 2                    PS                     10                  LT50
# 3                    PS                      4                    PS
# 4                   NaN                      1                    PS
#
# [5 rows x 4704 columns]
